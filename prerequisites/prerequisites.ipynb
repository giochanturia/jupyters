# %%
import pandas as pd
from pyvis.network import Network
import networkx as nx

import matplotlib.cm as cm
import matplotlib as matplotlib

# %%
database = pd.read_csv("nebula_physics.csv", delimiter=";")
color_map = lambda score: matplotlib.colors.rgb2hex(cm.RdYlGn((score-0.5)*2))
database["Color"] = database["Score"].apply(color_map)
# database = database.set_index('ID')
database
# Out:
#      ID                                             Name       Prerequisites  \
# 0   1.1                      1.1. ვექტორები და სკალარები                 NaN
# 1   1.2                              1.2. ვექტორული ჯამი                 1.1
# 2   1.3                       1.3. ვექტორის კომპონენტები            1.1, 1.2
# 3   2.1             2.1. გავლილი მანძილი vs გადაადგილება                 1.1
# 4   2.2                 2.2. საშუალო სიჩქარე და სისწრაფე                 2.1
# 5   2.3                            2.3. ათვლის სისტემები                 2.2
# 6   2.4                                    2.4. აჩქარება                 2.2
# 7   2.5    2.5. კიდევ ერთი ფორმულა მუდმივი აჩქარებისთვის            2.2, 2.4
# 8   3.1                           3.1. მოძრაობის სახეები       2.1, 2.2, 2.4
# 9   3.2             3.2. მოძრაობის სახეები მათემატიკურად            3.1, 2.5
# 10  3.3                     3.3. კუთხით გასროლილი სხეული            1.3, 3.2
# 11  3.4                           3.4. წრიული მოძრაობა 1       1.2, 2.2, 2.4
# 12  3.5                           3.5. წრიული მოძრაობა 2                 3.4
# 13  3.6                3.6. მოძრაობის სახეები: გრაფიკები            3.1, 3.2
# 14  4.1                     4.1. ნიუტონის პირველი კანონი            1.1, 1.2
# 15  4.2                       4.2. ნიუტონის მეორე კანონი            1.1, 2.4
# 16  4.3             4.3. ნიუტონის მეორე კანონის მაგალითი                 4.2
# 17  4.4  4.4. ნიუტონის მეორე კანონის კიდევ ერთი მაგალითი                 4.2
# 18  5.1                                  5.1. გრავიტაცია            2.4, 4.2
# 19  5.2   5.2. R კვადრატის უკუპროპორციულობა გრავიტაციაში                 5.1
# 20  5.3                      5.3. გრავიტაციის მაგალითები                 5.1
# 21  5.4         5.4. გრავიტაცია და ნიუტონის მეორე კანონი            5.1, 4.2
# 22  5.5                                5.5. ხახუნის ძალა       1.1, 1.3, 5.1
# 23  5.6                             5.6. დრეკადობის ძალა  1.1, 1.3, 4.1, 5.1
# 24  5.7                      5.7. ნიუტონის მესამე კანონი                 1.1
# 25  6.1                               6.1. ძალის მომენტი            1.1, 5.1
# 26  6.2                  6.2. ძალის მომენტის განზოგადება            1.3, 6.1
# 27  6.3                                6.3. ჭოჭონაქები 1            4.2, 5.1
# 28  6.4                                6.4. ჭოჭონაქები 2                 6.3
#
#     Score    Color
# 0    0.95  #199750
# 1    0.91  #57b65f
# 2    0.92  #45ad5b
# 3    0.93  #36a657
# 4    0.90  #66bd63
# 5    0.94  #279f53
# 6    0.91  #57b65f
# 7    0.72  #feec9f
# 8    0.90  #66bd63
# 9    0.50  #a50026
# 10   0.40  #a50026
# 11   0.92  #45ad5b
# 12   0.94  #279f53
# 13   0.67  #fdc372
# 14   0.92  #45ad5b
# 15   0.93  #36a657
# 16   0.91  #57b65f
# 17   0.95  #199750
# 18   0.93  #36a657
# 19   0.91  #57b65f
# 20   0.90  #66bd63
# 21   0.98  #0a7b41
# 22   0.97  #0f8446
# 23   0.95  #199750
# 24   0.91  #57b65f
# 25   0.92  #45ad5b
# 26   0.93  #36a657
# 27   0.94  #279f53
# 28   0.95  #199750

# %% [markdown]
# # Table generation

# %% [markdown]
# ## Prerequisite table

# %%
prereq_table = r"<table>"
prereq_table += "\n" + fr"<thead><tr><td><b>გაკვეთილი</b></td><td><b>პრერეკვიზიტები</b></td></tr></thead>"

for lesson in  database.iloc:
    prereq_table += "\n" + fr"<tr><td>{lesson['Name']}</td><td>{lesson['Prerequisites']}</td></tr>"

prereq_table += "\n" + r"</table>"

# %%
student_table = r"<table>"
student_table += "\n" + fr"<thead><tr><td><b>გაკვეთილი</b></td><td><b>ქულა</b></td></tr></thead>"

for lesson in  database.iloc:
    student_table += "\n" + fr"<tr style='color:{lesson['Color']};'><td>{lesson['Name']}</td><td>{lesson['Score']}</td></tr>"

student_table += "\n" + r"</table>"

# %%
with open("tables.html", "w") as table_html:
    table_html.write(prereq_table)
    table_html.write("\n\n")
    table_html.write(student_table)

# %% [markdown]
# # Graph generation

# %% [markdown]
# ## Prerequisite graph

# %%
nx_graph = nx.DiGraph()

for lesson in database.iloc:
    color = "#00000060"
    nx_graph.add_node(str(lesson["ID"]), title=str(lesson["Name"]), color=color)

for lesson in database.iloc:
    if str(lesson["Prerequisites"]) == "nan":
        continue
    color = "#00000020"
    for prerequisite in str(lesson["Prerequisites"]).split(", "):
        nx_graph.add_edge(str(prerequisite), str(lesson["ID"]), color=color)

# %%
nt = Network('700px', '700px', directed=True)
# populates the nodes and edges data structures
nt.from_nx(nx_graph)
nt.show('nx_0.html')

# %% [markdown]
# ## Student-dependent graph

# %%
problematic_lessons = list()

for problematic_entry in database[database["Score"] < 0.9].iloc:
    problematic_lessons.append(problematic_entry["ID"])
    problematic_lessons += map(float, problematic_entry["Prerequisites"].split(', '))

# %%
nx_graph = nx.DiGraph()

for lesson in database.iloc:
    color = lesson["Color"]
    if lesson["ID"] not in problematic_lessons:
        color = color + "20"
    nx_graph.add_node(str(lesson["ID"]), title=str(lesson["Name"]), color=color)

for lesson in database.iloc:
    if str(lesson["Prerequisites"]) == "nan":
        continue
    color = "#00000010"
    if lesson["Score"] < 0.9:
        color = "orange"
    for prerequisite in str(lesson["Prerequisites"]).split(", "):
        nx_graph.add_edge(str(prerequisite), str(lesson["ID"]), color=color)

# %%
nt = Network('700px', '700px', directed=True)
# populates the nodes and edges data structures
nt.from_nx(nx_graph)
nt.show('nx_student.html')

# %% [markdown]
# ## Student-dependent graph (student B)

# %%
database["Score"][27] = 0.4
database["Score"][28] = 0.3
database["Color"][27] = color_map(database["Score"][27])
database["Color"][28] = color_map(database["Score"][28])
# Out:
# /tmp/ipykernel_8661/1917686371.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   database["Score"][27] = 0.4
# /tmp/ipykernel_8661/1917686371.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   database["Score"][28] = 0.3
# /tmp/ipykernel_8661/1917686371.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   database["Color"][27] = color_map(database["Score"][27])
# /tmp/ipykernel_8661/1917686371.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   database["Color"][28] = color_map(database["Score"][28])

# %%
problematic_lessons = list()

for problematic_entry in database[database["Score"] < 0.9].iloc:
    problematic_lessons.append(problematic_entry["ID"])
    problematic_lessons += map(float, problematic_entry["Prerequisites"].split(', '))

# %%
nx_graph = nx.DiGraph()

for lesson in database.iloc:
    color = lesson["Color"]
    if lesson["ID"] not in problematic_lessons:
        color = color + "20"
    nx_graph.add_node(str(lesson["ID"]), title=str(lesson["Name"]), color=color)

for lesson in database.iloc:
    if str(lesson["Prerequisites"]) == "nan":
        continue
    color = "#00000010"
    if lesson["Score"] < 0.9:
        color = "orange"
    for prerequisite in str(lesson["Prerequisites"]).split(", "):
        nx_graph.add_edge(str(prerequisite), str(lesson["ID"]), color=color)

# %%
nt = Network('700px', '700px', directed=True)
# populates the nodes and edges data structures
nt.from_nx(nx_graph)
nt.show('nx_student_b.html')

# %%
database[database["Score"] < 0.9]
# Out:
#      ID                                           Name Prerequisites  Score  \
# 7   2.5  2.5. კიდევ ერთი ფორმულა მუდმივი აჩქარებისთვის      2.2, 2.4   0.72
# 9   3.2           3.2. მოძრაობის სახეები მათემატიკურად      3.1, 2.5   0.50
# 10  3.3                   3.3. კუთხით გასროლილი სხეული      1.3, 3.2   0.40
# 13  3.6              3.6. მოძრაობის სახეები: გრაფიკები      3.1, 3.2   0.67
# 27  6.3                              6.3. ჭოჭონაქები 1      4.2, 5.1   0.40
# 28  6.4                              6.4. ჭოჭონაქები 2           6.3   0.30
#
#       Color
# 7   #feec9f
# 9   #a50026
# 10  #a50026
# 13  #fdc372
# 27  #a50026
# 28  #a50026
