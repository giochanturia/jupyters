# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
a = 10
n = np.arange(1000) + 1
nlog = np.log(n)

# %%
nlogmean = nlog.cumsum() / n

# %%
plt.plot(nlog)
plt.plot(nlogmean)
plt.axhline(np.log(a), c='r', linestyle='dashed')
plt.show()
